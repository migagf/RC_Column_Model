# %% [markdown]
# ### Failure Mode Classification
# In this Jupyter Notebook we are training multiple ML models, aiming at predicting the failure mode of an RC column, based on data published in the PEER performance database

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
column_data = pd.read_csv('data_all.csv')

column_data
# Out:
#      Unnamed: 0  UniqueId                                    Name  \
# 0             0       222       Paultre et al., 2001, No. 1206040
# 1             1       367               Kowalsky et al. 1996, FL2
# 2             2       275                  Ang et al. 1985, No. 9
# 3             3       330             Arakawa et al. 1987, No. 13
# 4             4        19             Tanaka and Park 1990, No. 2
# ..          ...       ...                                     ...
# 286         286       165         Saatcioglu and Grira 1999, BG-1
# 287         287        77  Wight and Sozen 1973, No. 40.048(West)
# 288         288        98             Umehara and Jirsa 1982, CUS
# 289         289        61              Muguruma et al. 1989, BH-1
# 290         290       173         Saatcioglu and Grira 1999, BG-9
#
#             Type    FailureType        ar       lrr       srr       alr  \
# 0    Rectangular        Flexure  6.557377  0.104897  0.074735  0.413454
# ...

# %%
# Run lasso regression using ['ar', 'lrr', 'srr', 'alr', 'sdr', 'smr'] as features and 'Type' as the target variable
